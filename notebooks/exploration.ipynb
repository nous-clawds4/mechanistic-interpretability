# %% [markdown]
# # Exploration (Deprecated / Redirect)
#
# The active notebook for **Phase 1: Feature Discovery** is now:
#
# **[notebooks/phase1_feature_discovery.ipynb](./phase1_feature_discovery.ipynb)**
#
# This file is kept for git history / backward references only.
#
# See `EXPERIMENTS.md` for current status.
